# %% [markdown]
# # Feature Extraction

# %% [markdown]
# In this notebook, we are performing feature extraction to transform raw match data into meaningful insights for analysis and predictive modeling. <br>
# By deriving key features from the dataset, we aim to enhance the model’s ability to predict total runs in an IPL innings.

# %% [markdown]
# Feature extraction involves identifying important patterns and relationships within the data, which helps improve accuracy and efficiency in further processing. <br>
# This step is crucial for building a robust ML model by ensuring that only the most relevant and informative data is used.

# %% [markdown]
# Through this process, we are refining the dataset, making it more structured and valuable for our predictive analysis.

# %% [markdown]
# The aim is to extract the following information:
# 1. Batting team
# 2. Bowling team
# 3. City
# 4. Current score
# 5. Balls left
# 6. Wickets left
# 7. Current run rate
# 8. Score in the last five overs
# 9. Total runs scored

# %%
import pandas as pd
import pickle

# %%
df = pickle.load(open('dataset_level2.pkl', 'rb'))

# %%
df
# Out:
#         match_id         batting_team                 bowling_team  ball  \
# 0              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.1
# 1              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.2
# 2              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.3
# 3              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.4
# 4              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.5
# ...          ...                  ...                          ...   ...
# 135013      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.2
# 135014      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.3
# 135015      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.4
# 135016      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.5
# 135017      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.6
#
#         runs player_dismissed       city  \
# 0          0                0  Hyderabad
# 1          0                0  Hyderabad
# 2          4                0  Hyderabad
# 3          0                0  Hyderabad
# 4          2                0  Hyderabad
# ...      ...              ...        ...
# 135013     6                0  Bangalore
# 135014     6                0  Bangalore
# 135015     1                0  Bangalore
# 135016     1                0  Bangalore
# 135017     6                0  Bangalore
#
#                                             venue
# 0       Rajiv Gandhi International Stadium, Uppal
# 1       Rajiv Gandhi International Stadium, Uppal
# 2       Rajiv Gandhi International Stadium, Uppal
# 3       Rajiv Gandhi International Stadium, Uppal
# 4       Rajiv Gandhi International Stadium, Uppal
# ...                                           ...
# 135013                      M Chinnaswamy Stadium
# 135014                      M Chinnaswamy Stadium
# 135015                      M Chinnaswamy Stadium
# 135016                      M Chinnaswamy Stadium
# 135017                      M Chinnaswamy Stadium
#
# [135018 rows x 8 columns]

# %% [markdown]
# # Handling missing data

# %% [markdown]
# We are identifying and handling missing (null) values in the dataset to ensure data consistency and accuracy. <br>
# Missing values can impact the quality of the analysis and predictions, so it is essential to address them appropriately.

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                6343
# venue                  0
# dtype: int64

# %%
df['city'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 135013    False
# 135014    False
# 135015    False
# 135016    False
# 135017    False
# Name: city, Length: 135018, dtype: bool

# %% [markdown]
# We are identifying that some values in the city column are NaN (missing), which needs to be addressed to maintain data accuracy. <br>
# Since the city information is essential for analysis, we are working on filling these missing values.

# %%
df[df['city'].isnull()]
# Out:
#         match_id         batting_team     bowling_team  ball  runs  \
# 22095        182       Delhi Capitals  Kings XI Punjab   0.1     0
# 22096        182       Delhi Capitals  Kings XI Punjab   0.2     0
# 22097        182       Delhi Capitals  Kings XI Punjab   0.3     0
# 22098        182       Delhi Capitals  Kings XI Punjab   0.4     4
# 22099        182       Delhi Capitals  Kings XI Punjab   0.5     1
# ...          ...                  ...              ...   ...   ...
# 115558       937  Sunrisers Hyderabad   Mumbai Indians  19.2     0
# 115559       937  Sunrisers Hyderabad   Mumbai Indians  19.3     1
# 115560       937  Sunrisers Hyderabad   Mumbai Indians  19.4     1
# 115561       937  Sunrisers Hyderabad   Mumbai Indians  19.5     4
# 115562       937  Sunrisers Hyderabad   Mumbai Indians  19.6     4
#
#        player_dismissed city                                venue
# 22095                 0  NaN  Dubai International Cricket Stadium
# 22096                 0  NaN  Dubai International Cricket Stadium
# 22097                 0  NaN  Dubai International Cricket Stadium
# 22098                 0  NaN  Dubai International Cricket Stadium
# 22099                 0  NaN  Dubai International Cricket Stadium
# ...                 ...  ...                                  ...
# 115558         KL Rahul  NaN  Dubai International Cricket Stadium
# 115559                0  NaN  Dubai International Cricket Stadium
# 115560                0  NaN  Dubai International Cricket Stadium
# 115561                0  NaN  Dubai International Cricket Stadium
# 115562                0  NaN  Dubai International Cricket Stadium
#
# [6343 rows x 8 columns]

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium    4106
# Sharjah Cricket Stadium                2237
# Name: count, dtype: int64

# %%
4106 + 2237
# Out:
# 6343

# %% [markdown]
# During testing, we identified two instances where the city information was missing:
# 1. Dubai International Cricket Stadium
# 2. Sharjah Cricket Stadium

# %% [markdown]
# To resolve this, we can manually replace these values by referencing their respective cities. <br>
# For larger datasets, alternative approaches can be used to efficiently handle missing data.

# %%
df.loc[df['venue'] == 'Dubai International Cricket Stadium', 'city'] = 'Dubai'

# %%
df.loc[df['venue'] == 'Sharjah Cricket Stadium', 'city'] = 'Sharjah'

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %% [markdown]
# Every null value has been resolved.

# %%
df['city'].value_counts()
# Out:
# city
# Mumbai            21504
# Kolkata           11380
# Delhi             11059
# Chennai           10554
# Hyderabad          9499
# Bangalore          7869
# Chandigarh         7449
# Jaipur             7073
# Pune               6300
# Dubai              5729
# Abu Dhabi          4565
# Ahmedabad          4450
# Bengaluru          3521
# Sharjah            3482
# Visakhapatnam      1869
# Durban             1858
# Lucknow            1738
# Dharamsala         1618
# Centurion          1486
# Rajkot             1229
# Navi Mumbai        1133
# Indore             1082
# Johannesburg        995
# Port Elizabeth      870
# Cuttack             856
# Ranchi              837
# Cape Town           813
# Raipur              742
# Mohali              622
# Kochi               603
# Kanpur              492
# East London         380
# Guwahati            372
# Nagpur              370
# Kimberley           368
# Bloemfontein        251
# Name: count, dtype: int64

# %%
df.drop(columns=['venue'], inplace=True)

# %%
df.shape
# Out:
# (135018, 7)

# %%
df.columns
# Out:
# Index(['match_id', 'batting_team', 'bowling_team', 'ball', 'runs',
#        'player_dismissed', 'city'],
#       dtype='object')

# %% [markdown]
# We are identifying venues where 600 or fewer balls have been bowled, as such venues do not provide enough data to effectively train the model. <br> Since a limited number of deliveries may not capture match dynamics accurately, we are ensuring that only venues with sufficient data are retained.

# %%
df['city'].value_counts()
# Out:
# city
# Mumbai            21504
# Kolkata           11380
# Delhi             11059
# Chennai           10554
# Hyderabad          9499
# Bangalore          7869
# Chandigarh         7449
# Jaipur             7073
# Pune               6300
# Dubai              5729
# Abu Dhabi          4565
# Ahmedabad          4450
# Bengaluru          3521
# Sharjah            3482
# Visakhapatnam      1869
# Durban             1858
# Lucknow            1738
# Dharamsala         1618
# Centurion          1486
# Rajkot             1229
# Navi Mumbai        1133
# Indore             1082
# Johannesburg        995
# Port Elizabeth      870
# Cuttack             856
# Ranchi              837
# Cape Town           813
# Raipur              742
# Mohali              622
# Kochi               603
# Kanpur              492
# East London         380
# Guwahati            372
# Nagpur              370
# Kimberley           368
# Bloemfontein        251
# Name: count, dtype: int64

# %%
df['city'].value_counts()[df['city'].value_counts() > 600]
# Out:
# city
# Mumbai            21504
# Kolkata           11380
# Delhi             11059
# Chennai           10554
# Hyderabad          9499
# Bangalore          7869
# Chandigarh         7449
# Jaipur             7073
# Pune               6300
# Dubai              5729
# Abu Dhabi          4565
# Ahmedabad          4450
# Bengaluru          3521
# Sharjah            3482
# Visakhapatnam      1869
# Durban             1858
# Lucknow            1738
# Dharamsala         1618
# Centurion          1486
# Rajkot             1229
# Navi Mumbai        1133
# Indore             1082
# Johannesburg        995
# Port Elizabeth      870
# Cuttack             856
# Ranchi              837
# Cape Town           813
# Raipur              742
# Mohali              622
# Kochi               603
# Name: count, dtype: int64

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df['city'].value_counts()
# Out:
# city
# Mumbai            21504
# Kolkata           11380
# Delhi             11059
# Chennai           10554
# Hyderabad          9499
# Bangalore          7869
# Chandigarh         7449
# Jaipur             7073
# Pune               6300
# Dubai              5729
# Abu Dhabi          4565
# Ahmedabad          4450
# Bengaluru          3521
# Sharjah            3482
# Visakhapatnam      1869
# Durban             1858
# Lucknow            1738
# Dharamsala         1618
# Centurion          1486
# Rajkot             1229
# Navi Mumbai        1133
# Indore             1082
# Johannesburg        995
# Port Elizabeth      870
# Cuttack             856
# Ranchi              837
# Cape Town           813
# Raipur              742
# Mohali              622
# Kochi               603
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (132785, 7)

# %% [markdown]
# We are determining the current score of the batting team by computing the cumulative sum of runs from the dataset. <br>
# This helps track the team's total runs at any given point in the innings.

# %%
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\2100093582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runs'] = pd.to_numeric(df['runs'], errors='coerce')

# %%
df
# Out:
#         match_id         batting_team                 bowling_team  ball  \
# 0              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.1
# 1              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.2
# 2              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.3
# 3              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.4
# 4              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.5
# ...          ...                  ...                          ...   ...
# 135013      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.2
# 135014      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.3
# 135015      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.4
# 135016      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.5
# 135017      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.6
#
#         runs player_dismissed       city
# 0          0                0  Hyderabad
# 1          0                0  Hyderabad
# 2          4                0  Hyderabad
# 3          0                0  Hyderabad
# 4          2                0  Hyderabad
# ...      ...              ...        ...
# 135013     6                0  Bangalore
# 135014     6                0  Bangalore
# 135015     1                0  Bangalore
# 135016     1                0  Bangalore
# 135017     6                0  Bangalore
#
# [132785 rows x 7 columns]

# %%
df['runs'].dtype
# Out:
# dtype('int64')

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\190681986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#         match_id         batting_team                 bowling_team  ball  \
# 0              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.1
# 1              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.2
# 2              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.3
# 3              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.4
# 4              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.5
# ...          ...                  ...                          ...   ...
# 135013      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.2
# 135014      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.3
# 135015      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.4
# 135016      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.5
# 135017      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.6
#
#         runs player_dismissed       city  current_score
# 0          0                0  Hyderabad              0
# 1          0                0  Hyderabad              0
# 2          4                0  Hyderabad              4
# 3          0                0  Hyderabad              4
# 4          2                0  Hyderabad              6
# ...      ...              ...        ...            ...
# 135013     6                0  Bangalore            194
# 135014     6                0  Bangalore            200
# 135015     1                0  Bangalore            201
# 135016     1                0  Bangalore            202
# 135017     6                0  Bangalore            208
#
# [132785 rows x 8 columns]

# %% [markdown]
# We are extracting the ball number from the over data, which is currently represented in a decimal format
# (e.g., 5.3 for the third ball of the sixth over). <br>
# To simplify further processing, we are converting this into a standardized format.

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\1757844946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\1757844946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df
# Out:
#         match_id         batting_team                 bowling_team  ball  \
# 0              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.1
# 1              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.2
# 2              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.3
# 3              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.4
# 4              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.5
# ...          ...                  ...                          ...   ...
# 135013      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.2
# 135014      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.3
# 135015      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.4
# 135016      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.5
# 135017      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.6
#
#         runs player_dismissed       city  current_score over ball_no
# 0          0                0  Hyderabad              0    0       1
# 1          0                0  Hyderabad              0    0       2
# 2          4                0  Hyderabad              4    0       3
# 3          0                0  Hyderabad              4    0       4
# 4          2                0  Hyderabad              6    0       5
# ...      ...              ...        ...            ...  ...     ...
# 135013     6                0  Bangalore            194   19       2
# 135014     6                0  Bangalore            200   19       3
# 135015     1                0  Bangalore            201   19       4
# 135016     1                0  Bangalore            202   19       5
# 135017     6                0  Bangalore            208   19       6
#
# [132785 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\572800509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')

# %%
df
# Out:
#         match_id         batting_team                 bowling_team  ball  \
# 0              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.1
# 1              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.2
# 2              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.3
# 3              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.4
# 4              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.5
# ...          ...                  ...                          ...   ...
# 135013      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.2
# 135014      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.3
# 135015      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.4
# 135016      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.5
# 135017      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.6
#
#         runs player_dismissed       city  current_score over ball_no  \
# 0          0                0  Hyderabad              0    0       1
# 1          0                0  Hyderabad              0    0       2
# 2          4                0  Hyderabad              4    0       3
# 3          0                0  Hyderabad              4    0       4
# 4          2                0  Hyderabad              6    0       5
# ...      ...              ...        ...            ...  ...     ...
# 135013     6                0  Bangalore            194   19       2
# 135014     6                0  Bangalore            200   19       3
# 135015     1                0  Bangalore            201   19       4
# 135016     1                0  Bangalore            202   19       5
# 135017     6                0  Bangalore            208   19       6
#
#         balls_bowled
# 0                  1
# 1                  2
# 2                  3
# 3                  4
# 4                  5
# ...              ...
# 135013           116
# 135014           117
# 135015           118
# 135016           119
# 135017           120
#
# [132785 rows x 11 columns]

# %% [markdown]
# We are determining the number of balls left in the match using the extracted ball number. <br>Since a T20 match consists of 120 balls per innings, we can compute the remaining deliveries at any stage of the game. <br> By calculating the balls left, we are enhancing the dataset with an important feature that helps in understanding the match situation and improving predictive modeling.

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\1113636379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\1113636379.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
df
# Out:
#         match_id         batting_team                 bowling_team  ball  \
# 0              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.1
# 1              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.2
# 2              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.3
# 3              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.4
# 4              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.5
# ...          ...                  ...                          ...   ...
# 135013      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.2
# 135014      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.3
# 135015      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.4
# 135016      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.5
# 135017      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.6
#
#         runs player_dismissed       city  current_score over ball_no  \
# 0          0                0  Hyderabad              0    0       1
# 1          0                0  Hyderabad              0    0       2
# 2          4                0  Hyderabad              4    0       3
# 3          0                0  Hyderabad              4    0       4
# 4          2                0  Hyderabad              6    0       5
# ...      ...              ...        ...            ...  ...     ...
# 135013     6                0  Bangalore            194   19       2
# 135014     6                0  Bangalore            200   19       3
# 135015     1                0  Bangalore            201   19       4
# 135016     1                0  Bangalore            202   19       5
# 135017     6                0  Bangalore            208   19       6
#
#         balls_bowled  balls_left
# 0                  1         119
# 1                  2         118
# 2                  3         117
# 3                  4         116
# 4                  5         115
# ...              ...         ...
# 135013           116           4
# 135014           117           3
# 135015           118           2
# 135016           119           1
# 135017           120           0
#
# [132785 rows x 12 columns]

# %% [markdown]
# We are determining the number of wickets left in the innings using the dismissed player data. <br>
# Since each team starts with 10 wickets, tracking dismissals helps analyze match progression. <br>
# By computing wickets left, we are enhancing match analysis and capturing a key feature for predicting team performance.

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\739840433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)

# %%
df['player_dismissed'].value_counts()
# Out:
# player_dismissed
# 0    126213
# 1      6572
# Name: count, dtype: int64

# %%
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\2974175751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\2974175751.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\2974175751.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#         match_id         batting_team                 bowling_team  ball  \
# 0              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.1
# 1              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.2
# 2              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.3
# 3              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.4
# 4              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.5
# ...          ...                  ...                          ...   ...
# 135013      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.2
# 135014      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.3
# 135015      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.4
# 135016      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.5
# 135017      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.6
#
#         runs  player_dismissed       city  current_score over ball_no  \
# 0          0                 0  Hyderabad              0    0       1
# 1          0                 0  Hyderabad              0    0       2
# 2          4                 0  Hyderabad              4    0       3
# 3          0                 0  Hyderabad              4    0       4
# 4          2                 0  Hyderabad              6    0       5
# ...      ...               ...        ...            ...  ...     ...
# 135013     6                 7  Bangalore            194   19       2
# 135014     6                 7  Bangalore            200   19       3
# 135015     1                 7  Bangalore            201   19       4
# 135016     1                 7  Bangalore            202   19       5
# 135017     6                 7  Bangalore            208   19       6
#
#         balls_bowled  balls_left  wickets_left
# 0                  1         119            10
# 1                  2         118            10
# 2                  3         117            10
# 3                  4         116            10
# 4                  5         115            10
# ...              ...         ...           ...
# 135013           116           4             3
# 135014           117           3             3
# 135015           118           2             3
# 135016           119           1             3
# 135017           120           0             3
#
# [132785 rows x 13 columns]

# %%
df['wickets_left'].value_counts()
# Out:
# wickets_left
# 9     26303
# 10    26228
# 8     23790
# 7     19486
# 6     15812
# 5      9845
# 4      5792
# 3      3027
# 2      1617
# 1       814
# 0        71
# Name: count, dtype: int64

# %% [markdown]
# We are determining the Current Run Rate (CRR) at each delivery. <br>It is the measure of the team's scoring pace by calculating the average runs scored per over. <br> This is a crucial metric for analyzing a team's performance in real-time.

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\914577034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#         match_id         batting_team                 bowling_team  ball  \
# 0              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.1
# 1              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.2
# 2              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.3
# 3              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.4
# 4              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.5
# ...          ...                  ...                          ...   ...
# 135013      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.2
# 135014      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.3
# 135015      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.4
# 135016      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.5
# 135017      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.6
#
#         runs  player_dismissed       city  current_score over ball_no  \
# 0          0                 0  Hyderabad              0    0       1
# 1          0                 0  Hyderabad              0    0       2
# 2          4                 0  Hyderabad              4    0       3
# 3          0                 0  Hyderabad              4    0       4
# 4          2                 0  Hyderabad              6    0       5
# ...      ...               ...        ...            ...  ...     ...
# 135013     6                 7  Bangalore            194   19       2
# 135014     6                 7  Bangalore            200   19       3
# 135015     1                 7  Bangalore            201   19       4
# 135016     1                 7  Bangalore            202   19       5
# 135017     6                 7  Bangalore            208   19       6
#
#         balls_bowled  balls_left  wickets_left        crr
# 0                  1         119            10   0.000000
# 1                  2         118            10   0.000000
# 2                  3         117            10   8.000000
# 3                  4         116            10   6.000000
# 4                  5         115            10   7.200000
# ...              ...         ...           ...        ...
# 135013           116           4             3  10.034483
# 135014           117           3             3  10.256410
# 135015           118           2             3  10.220339
# 135016           119           1             3  10.184874
# 135017           120           0             3  10.400000
#
# [132785 rows x 14 columns]

# %% [markdown]
# We are determining the total runs scored in the last five overs to capture the team's recent scoring momentum. <br>
# This feature is crucial for understanding how aggressively the team is playing in the final phase of the innings.

# %%
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')

groups = df.groupby('match_id')
match_ids = df['match_id'].unique()

last_five = []
for id in match_ids:
    group = groups.get_group(id).copy()
    group['runs'] = pd.to_numeric(group['runs'], errors='coerce')
    rolling_sum = group['runs'].rolling(window=30).sum()
    last_five.extend(rolling_sum.tolist())
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\629145512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runs'] = pd.to_numeric(df['runs'], errors='coerce')

# %%
last_five[25:35]
# Out:
# [nan, nan, nan, nan, 38.0, 42.0, 42.0, 42.0, 46.0, 44.0]

# %%
df['last_five'] = last_five
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df
# Out:
#         match_id         batting_team                 bowling_team  ball  \
# 0              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.1
# 1              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.2
# 2              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.3
# 3              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.4
# 4              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.5
# ...          ...                  ...                          ...   ...
# 135013      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.2
# 135014      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.3
# 135015      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.4
# 135016      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.5
# 135017      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.6
#
#         runs  player_dismissed       city  current_score over ball_no  \
# 0          0                 0  Hyderabad              0    0       1
# 1          0                 0  Hyderabad              0    0       2
# 2          4                 0  Hyderabad              4    0       3
# 3          0                 0  Hyderabad              4    0       4
# 4          2                 0  Hyderabad              6    0       5
# ...      ...               ...        ...            ...  ...     ...
# 135013     6                 7  Bangalore            194   19       2
# 135014     6                 7  Bangalore            200   19       3
# 135015     1                 7  Bangalore            201   19       4
# 135016     1                 7  Bangalore            202   19       5
# 135017     6                 7  Bangalore            208   19       6
#
#         balls_bowled  balls_left  wickets_left        crr  last_five
# 0                  1         119            10   0.000000        NaN
# 1                  2         118            10   0.000000        NaN
# 2                  3         117            10   8.000000        NaN
# 3                  4         116            10   6.000000        NaN
# 4                  5         115            10   7.200000        NaN
# ...              ...         ...           ...        ...        ...
# 135013           116           4             3  10.034483       54.0
# 135014           117           3             3  10.256410       56.0
# 135015           118           2             3  10.220339       56.0
# 135016           119           1             3  10.184874       57.0
# 135017           120           0             3  10.400000       62.0
#
# [132785 rows x 15 columns]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df
# Out:
#         match_id  runs_x         batting_team                 bowling_team  \
# 0              2     207  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              2     207  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              2     207  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              2     207  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              2     207  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 132780      1096     208  Sunrisers Hyderabad  Royal Challengers Bangalore
# 132781      1096     208  Sunrisers Hyderabad  Royal Challengers Bangalore
# 132782      1096     208  Sunrisers Hyderabad  Royal Challengers Bangalore
# 132783      1096     208  Sunrisers Hyderabad  Royal Challengers Bangalore
# 132784      1096     208  Sunrisers Hyderabad  Royal Challengers Bangalore
#
#         ball  runs_y  player_dismissed       city  current_score over ball_no  \
# 0        0.1       0                 0  Hyderabad              0    0       1
# 1        0.2       0                 0  Hyderabad              0    0       2
# 2        0.3       4                 0  Hyderabad              4    0       3
# 3        0.4       0                 0  Hyderabad              4    0       4
# 4        0.5       2                 0  Hyderabad              6    0       5
# ...      ...     ...               ...        ...            ...  ...     ...
# 132780  19.2       6                 7  Bangalore            194   19       2
# 132781  19.3       6                 7  Bangalore            200   19       3
# 132782  19.4       1                 7  Bangalore            201   19       4
# 132783  19.5       1                 7  Bangalore            202   19       5
# 132784  19.6       6                 7  Bangalore            208   19       6
#
#         balls_bowled  balls_left  wickets_left        crr  last_five
# 0                  1         119            10   0.000000        NaN
# 1                  2         118            10   0.000000        NaN
# 2                  3         117            10   8.000000        NaN
# 3                  4         116            10   6.000000        NaN
# 4                  5         115            10   7.200000        NaN
# ...              ...         ...           ...        ...        ...
# 132780           116           4             3  10.034483       54.0
# 132781           117           3             3  10.256410       56.0
# 132782           118           2             3  10.220339       56.0
# 132783           119           1             3  10.184874       57.0
# 132784           120           0             3  10.400000       62.0
#
# [132785 rows x 16 columns]

# %% [markdown]
# Formatting the dataset a bit more

# %%
final_df = final_df[['batting_team', 'bowling_team', 'city', 'current_score', 'balls_left', 'wickets_left', 'crr', 'last_five', 'runs_x']]

# %%
final_df
# Out:
#                batting_team                 bowling_team       city  \
# 0       Sunrisers Hyderabad  Royal Challengers Bangalore  Hyderabad
# 1       Sunrisers Hyderabad  Royal Challengers Bangalore  Hyderabad
# 2       Sunrisers Hyderabad  Royal Challengers Bangalore  Hyderabad
# 3       Sunrisers Hyderabad  Royal Challengers Bangalore  Hyderabad
# 4       Sunrisers Hyderabad  Royal Challengers Bangalore  Hyderabad
# ...                     ...                          ...        ...
# 132780  Sunrisers Hyderabad  Royal Challengers Bangalore  Bangalore
# 132781  Sunrisers Hyderabad  Royal Challengers Bangalore  Bangalore
# 132782  Sunrisers Hyderabad  Royal Challengers Bangalore  Bangalore
# 132783  Sunrisers Hyderabad  Royal Challengers Bangalore  Bangalore
# 132784  Sunrisers Hyderabad  Royal Challengers Bangalore  Bangalore
#
#         current_score  balls_left  wickets_left        crr  last_five  runs_x
# 0                   0         119            10   0.000000        NaN     207
# 1                   0         118            10   0.000000        NaN     207
# 2                   4         117            10   8.000000        NaN     207
# 3                   4         116            10   6.000000        NaN     207
# 4                   6         115            10   7.200000        NaN     207
# ...               ...         ...           ...        ...        ...     ...
# 132780            194           4             3  10.034483       54.0     208
# 132781            200           3             3  10.256410       56.0     208
# 132782            201           2             3  10.220339       56.0     208
# 132783            202           1             3  10.184874       57.0     208
# 132784            208           0             3  10.400000       62.0     208
#
# [132785 rows x 9 columns]

# %% [markdown]
# We are performing a final review of the dataset to identify and remove any remaining null (missing) values before proceeding with model training. <br>
# By conducting this final cleanup, we are ensuring that the dataset is free of inconsistencies, making it more reliable for feature extraction and model training.

# %%
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        31233
# runs_x               0
# dtype: int64

# %%
final_df.dropna(inplace=True)
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_21332\2709626079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df.shape
# Out:
# (101552, 9)

# %% [markdown]
# We are shuffling the dataset to ensure that the model does not learn any unintended patterns due to the original order of the data. <br>
# Randomizing the data helps in improving generalization and prevents the model from being biased toward specific sequences.

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#                        batting_team                 bowling_team       city  \
# 99674              Delhi Daredevils          Chennai Super Kings    Chennai
# 52863           Sunrisers Hyderabad         Lucknow Super Giants  Hyderabad
# 102778             Rajasthan Royals        Kolkata Knight Riders     Jaipur
# 19135   Royal Challengers Bangalore          Chennai Super Kings  Bengaluru
# 7717               Rajasthan Royals             Delhi Daredevils     Jaipur
# ...                             ...                          ...        ...
# 19944           Sunrisers Hyderabad             Rajasthan Royals     Jaipur
# 7510               Rajasthan Royals          Sunrisers Hyderabad  Hyderabad
# 79619              Delhi Daredevils  Royal Challengers Bangalore  Bangalore
# 101798          Chennai Super Kings        Kolkata Knight Riders    Chennai
# 120717             Delhi Daredevils        Kolkata Knight Riders      Delhi
#
#         current_score  balls_left  wickets_left       crr  last_five  runs_x
# 99674              78          30             5  5.200000       26.0     114
# 52863             173           5             4  9.026087       44.0     182
# 102778            104          21             5  6.303030       35.0     144
# 19135              58          80             9  8.700000       51.0     161
# 7717               99          49             7  8.366197       42.0     153
# ...               ...         ...           ...       ...        ...     ...
# 19944             137          11             4  7.541284       29.0     160
# 7510              117          12             3  6.500000       25.0     125
# 79619             172           4             6  8.896552       44.0     183
# 101798            161          16             8  9.288462       55.0     190
# 120717            103          31             6  6.943820       34.0     146
#
# [101552 rows x 9 columns]

# %% [markdown]
# We are saving the final cleaned and shuffled dataset as a pickle file to preserve progress before proceeding to model training. <br>
# This ensures that we can reload the dataset quickly without repeating the preprocessing steps.

# %%
pickle.dump(final_df, open('dataset_level3.pkl', 'wb'))

# %%
output_chk = pickle.load(open('dataset_level3.pkl', 'rb'))

# %%
output_chk
# Out:
#                        batting_team                 bowling_team       city  \
# 99674              Delhi Daredevils          Chennai Super Kings    Chennai
# 52863           Sunrisers Hyderabad         Lucknow Super Giants  Hyderabad
# 102778             Rajasthan Royals        Kolkata Knight Riders     Jaipur
# 19135   Royal Challengers Bangalore          Chennai Super Kings  Bengaluru
# 7717               Rajasthan Royals             Delhi Daredevils     Jaipur
# ...                             ...                          ...        ...
# 19944           Sunrisers Hyderabad             Rajasthan Royals     Jaipur
# 7510               Rajasthan Royals          Sunrisers Hyderabad  Hyderabad
# 79619              Delhi Daredevils  Royal Challengers Bangalore  Bangalore
# 101798          Chennai Super Kings        Kolkata Knight Riders    Chennai
# 120717             Delhi Daredevils        Kolkata Knight Riders      Delhi
#
#         current_score  balls_left  wickets_left       crr  last_five  runs_x
# 99674              78          30             5  5.200000       26.0     114
# 52863             173           5             4  9.026087       44.0     182
# 102778            104          21             5  6.303030       35.0     144
# 19135              58          80             9  8.700000       51.0     161
# 7717               99          49             7  8.366197       42.0     153
# ...               ...         ...           ...       ...        ...     ...
# 19944             137          11             4  7.541284       29.0     160
# 7510              117          12             3  6.500000       25.0     125
# 79619             172           4             6  8.896552       44.0     183
# 101798            161          16             8  9.288462       55.0     190
# 120717            103          31             6  6.943820       34.0     146
#
# [101552 rows x 9 columns]
