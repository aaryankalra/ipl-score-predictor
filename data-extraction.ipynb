# %% [markdown]
# # Data Extraction

# %% [markdown]
# This notebook focuses on retrieving and processing raw data for further analysis. <br>
# This step is crucial in ensuring that the data is well-structured, clean and ready for modeling.

# %% [markdown]
# **Key Objectives:**
# 1. Load and convert data into readable format
# 2. Handle missing and inconsistent data
# 3. Transform and structure data
# 4. Extract ball by ball data for efficient analysis

# %%
import pandas as pd
import numpy as np
from yaml import safe_load
import os
from tqdm import tqdm

# %% [markdown]
# Importing the match data stored in YAML format and converting it into a structured pandas DataFrame for further processing. <br>
# Since YAML is a human-readable format commonly used for configuration files and structured data storage, it is being parsed before working with it in Python.

# %%
filenames = []
for file in os.listdir('ipl-data'):
    filenames.append(os.path.join('ipl-data', file))

# %%
filenames[:5]
# Out:
# ['ipl-data\\1082591.yaml',
#  'ipl-data\\1082592.yaml',
#  'ipl-data\\1082593.yaml',
#  'ipl-data\\1082594.yaml',
#  'ipl-data\\1082595.yaml']

# %% [markdown]
# Since processing the next cell can take time, tqdm is being used to display a progress bar. <br>
# This is providing real-time feedback on the process, helping track execution time and improving usability.

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = pd.concat([final_df, df], ignore_index=True)
        counter+=1
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████▉| 1095/1096 [02:24<00:00,  7.55it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[4], line 5
#       3 for file in tqdm(filenames):
#       4     with open(file, 'r') as f:
# ----> 5         df = pd.json_normalize(safe_load(f))
#       6         df['match_id'] = counter
#       7         final_df = pd.concat([final_df, df], ignore_index=True)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\json\_normalize.py:445, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     443     data = list(data)
#     444 else:
# --> 445     raise NotImplementedError
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     450 if (
#     451     record_path is None
#     452     and meta is None
#    (...)
#     455     and max_level is None
#     456 ):
#
# NotImplementedError:

# %%
final_df
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Sunrisers Hyderabad...               0.91
# 1     [{'1st innings': {'team': 'Mumbai Indians', 'd...               0.91
# 2     [{'1st innings': {'team': 'Gujarat Lions', 'de...               0.91
# 3     [{'1st innings': {'team': 'Rising Pune Supergi...               0.91
# 4     [{'1st innings': {'team': 'Royal Challengers B...               0.91
# ...                                                 ...                ...
# 1090  [{'1st innings': {'team': 'Delhi Daredevils', ...               0.91
# 1091  [{'1st innings': {'team': 'Gujarat Lions', 'de...               0.91
# 1092  [{'1st innings': {'team': 'Sunrisers Hyderabad...               0.91
# 1093  [{'1st innings': {'team': 'Gujarat Lions', 'de...               0.91
# 1094  [{'1st innings': {'team': 'Sunrisers Hyderabad...               0.91
#
#      meta.created  meta.revision  info.balls_per_over  info.city  \
# 0      2017-04-06              1                    6  Hyderabad
# 1      2017-04-07              1                    6       Pune
# 2      2017-04-07              2                    6     Rajkot
# 3      2017-04-08              1                    6     Indore
# 4      2017-04-08              2                    6  Bengaluru
# ...           ...            ...                  ...        ...
# 1090   2016-05-23              1                    6     Raipur
# 1091   2016-05-24              1                    6  Bangalore
# 1092   2016-05-25              1                    6      Delhi
# 1093   2016-05-28              1                    6      Delhi
# 1094   2016-05-30              1                    6  Bangalore
#
#      info.competition    info.dates info.gender info.match_type  ...  \
# 0                 IPL  [2017-04-05]        male             T20  ...
# 1                 IPL  [2017-04-06]        male             T20  ...
# 2                 IPL  [2017-04-07]        male             T20  ...
# 3                 IPL  [2017-04-08]        male             T20  ...
# 4                 IPL  [2017-04-08]        male             T20  ...
# ...               ...           ...         ...             ...  ...
# 1090              IPL  [2016-05-22]        male             T20  ...
# 1091              IPL  [2016-05-24]        male             T20  ...
# 1092              IPL  [2016-05-25]        male             T20  ...
# 1093              IPL  [2016-05-27]        male             T20  ...
# 1094              IPL  [2016-05-29]        male             T20  ...
#
#       info.registry.people.B Aparajith info.registry.people.GS Sandhu  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# ...                                ...                            ...
# 1090                               NaN                            NaN
# 1091                               NaN                            NaN
# 1092                               NaN                            NaN
# 1093                               NaN                            NaN
# 1094                               NaN                            NaN
#
#       info.players.Rising Pune Supergiants info.registry.people.P Sahu  \
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
# 3                                      NaN                         NaN
# 4                                      NaN                         NaN
# ...                                    ...                         ...
# 1090                                   NaN                         NaN
# 1091                                   NaN                         NaN
# 1092                                   NaN                         NaN
# 1093                                   NaN                         NaN
# 1094                                   NaN                         NaN
#
#      info.registry.people.KJ Abbott info.registry.people.PSP Handscomb  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
# ...                             ...                                ...
# 1090                            NaN                                NaN
# 1091                            NaN                                NaN
# 1092                            NaN                                NaN
# 1093                            NaN                                NaN
# 1094                            NaN                                NaN
#
#      info.registry.people.SM Boland info.registry.people.UT Khawaja  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# ...                             ...                             ...
# 1090                            NaN                             NaN
# 1091                            NaN                             NaN
# 1092                            NaN                             NaN
# 1093                            NaN                             NaN
# 1094                            NaN                             NaN
#
#      info.registry.people.F Behardien info.registry.people.ER Dwivedi
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ...                               ...                             ...
# 1090                              NaN                             NaN
# 1091                              NaN                        b274dbbd
# 1092                              NaN                             NaN
# 1093                              NaN                        b274dbbd
# 1094                              NaN                             NaN
#
# [1095 rows x 927 columns]

# %% [markdown]
# Saving a copy of the extracted data to ensure data integrity before making further modifications.

# %%
backup = final_df.copy()

# %%
backup
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Sunrisers Hyderabad...               0.91
# 1     [{'1st innings': {'team': 'Mumbai Indians', 'd...               0.91
# 2     [{'1st innings': {'team': 'Gujarat Lions', 'de...               0.91
# 3     [{'1st innings': {'team': 'Rising Pune Supergi...               0.91
# 4     [{'1st innings': {'team': 'Royal Challengers B...               0.91
# ...                                                 ...                ...
# 1090  [{'1st innings': {'team': 'Delhi Daredevils', ...               0.91
# 1091  [{'1st innings': {'team': 'Gujarat Lions', 'de...               0.91
# 1092  [{'1st innings': {'team': 'Sunrisers Hyderabad...               0.91
# 1093  [{'1st innings': {'team': 'Gujarat Lions', 'de...               0.91
# 1094  [{'1st innings': {'team': 'Sunrisers Hyderabad...               0.91
#
#      meta.created  meta.revision  info.balls_per_over  info.city  \
# 0      2017-04-06              1                    6  Hyderabad
# 1      2017-04-07              1                    6       Pune
# 2      2017-04-07              2                    6     Rajkot
# 3      2017-04-08              1                    6     Indore
# 4      2017-04-08              2                    6  Bengaluru
# ...           ...            ...                  ...        ...
# 1090   2016-05-23              1                    6     Raipur
# 1091   2016-05-24              1                    6  Bangalore
# 1092   2016-05-25              1                    6      Delhi
# 1093   2016-05-28              1                    6      Delhi
# 1094   2016-05-30              1                    6  Bangalore
#
#      info.competition    info.dates info.gender info.match_type  ...  \
# 0                 IPL  [2017-04-05]        male             T20  ...
# 1                 IPL  [2017-04-06]        male             T20  ...
# 2                 IPL  [2017-04-07]        male             T20  ...
# 3                 IPL  [2017-04-08]        male             T20  ...
# 4                 IPL  [2017-04-08]        male             T20  ...
# ...               ...           ...         ...             ...  ...
# 1090              IPL  [2016-05-22]        male             T20  ...
# 1091              IPL  [2016-05-24]        male             T20  ...
# 1092              IPL  [2016-05-25]        male             T20  ...
# 1093              IPL  [2016-05-27]        male             T20  ...
# 1094              IPL  [2016-05-29]        male             T20  ...
#
#       info.registry.people.B Aparajith info.registry.people.GS Sandhu  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# ...                                ...                            ...
# 1090                               NaN                            NaN
# 1091                               NaN                            NaN
# 1092                               NaN                            NaN
# 1093                               NaN                            NaN
# 1094                               NaN                            NaN
#
#       info.players.Rising Pune Supergiants info.registry.people.P Sahu  \
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
# 3                                      NaN                         NaN
# 4                                      NaN                         NaN
# ...                                    ...                         ...
# 1090                                   NaN                         NaN
# 1091                                   NaN                         NaN
# 1092                                   NaN                         NaN
# 1093                                   NaN                         NaN
# 1094                                   NaN                         NaN
#
#      info.registry.people.KJ Abbott info.registry.people.PSP Handscomb  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
# ...                             ...                                ...
# 1090                            NaN                                NaN
# 1091                            NaN                                NaN
# 1092                            NaN                                NaN
# 1093                            NaN                                NaN
# 1094                            NaN                                NaN
#
#      info.registry.people.SM Boland info.registry.people.UT Khawaja  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# ...                             ...                             ...
# 1090                            NaN                             NaN
# 1091                            NaN                             NaN
# 1092                            NaN                             NaN
# 1093                            NaN                             NaN
# 1094                            NaN                             NaN
#
#      info.registry.people.F Behardien info.registry.people.ER Dwivedi
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ...                               ...                             ...
# 1090                              NaN                             NaN
# 1091                              NaN                        b274dbbd
# 1092                              NaN                             NaN
# 1093                              NaN                        b274dbbd
# 1094                              NaN                             NaN
#
# [1095 rows x 927 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# After extracting the data, the next step is to clean it to ensure consistency, accuracy, and usability for further analysis.

# %% [markdown]
# Removing unnecessary columns and retaining only the essential ones to optimize data processing and improve analysis. <br>
# This step is helping reduce memory usage and eliminating irrelevant information.

# %%
final_df.shape
# Out:
# (1095, 927)

# %%
final_df.columns[:14]
# Out:
# Index(['innings', 'meta.data_version', 'meta.created', 'meta.revision',
#        'info.balls_per_over', 'info.city', 'info.competition', 'info.dates',
#        'info.gender', 'info.match_type', 'info.outcome.by.runs',
#        'info.outcome.winner', 'info.overs', 'info.player_of_match'],
#       dtype='object')

# %%
final_df.columns[45:51]
# Out:
# Index(['info.toss.decision', 'info.toss.winner', 'info.umpires', 'info.venue',
#        'match_id', 'info.outcome.by.wickets'],
#       dtype='object')

# %%
if 'info.teams' in final_df.columns:
    print("true")
# Out:
# true

# %%
final_df = final_df[['innings', 'info.city', 'info.teams', 'info.competition', 'info.dates', 'info.gender', 'info.match_type', 'info.overs', 'info.outcome.winner', 'info.player_of_match', 'info.toss.decision', 'info.toss.winner', 'info.umpires', 'info.venue', 'match_id']]

# %%
final_df
# Out:
#                                                 innings  info.city  \
# 0     [{'1st innings': {'team': 'Sunrisers Hyderabad...  Hyderabad
# 1     [{'1st innings': {'team': 'Mumbai Indians', 'd...       Pune
# 2     [{'1st innings': {'team': 'Gujarat Lions', 'de...     Rajkot
# 3     [{'1st innings': {'team': 'Rising Pune Supergi...     Indore
# 4     [{'1st innings': {'team': 'Royal Challengers B...  Bengaluru
# ...                                                 ...        ...
# 1090  [{'1st innings': {'team': 'Delhi Daredevils', ...     Raipur
# 1091  [{'1st innings': {'team': 'Gujarat Lions', 'de...  Bangalore
# 1092  [{'1st innings': {'team': 'Sunrisers Hyderabad...      Delhi
# 1093  [{'1st innings': {'team': 'Gujarat Lions', 'de...      Delhi
# 1094  [{'1st innings': {'team': 'Sunrisers Hyderabad...  Bangalore
#
#                                              info.teams info.competition  \
# 0     [Sunrisers Hyderabad, Royal Challengers Bangal...              IPL
# 1              [Rising Pune Supergiant, Mumbai Indians]              IPL
# 2                [Gujarat Lions, Kolkata Knight Riders]              IPL
# 3             [Kings XI Punjab, Rising Pune Supergiant]              IPL
# 4       [Royal Challengers Bangalore, Delhi Daredevils]              IPL
# ...                                                 ...              ...
# 1090    [Delhi Daredevils, Royal Challengers Bangalore]              IPL
# 1091       [Gujarat Lions, Royal Challengers Bangalore]              IPL
# 1092       [Sunrisers Hyderabad, Kolkata Knight Riders]              IPL
# 1093               [Gujarat Lions, Sunrisers Hyderabad]              IPL
# 1094  [Royal Challengers Bangalore, Sunrisers Hydera...              IPL
#
#         info.dates info.gender info.match_type  info.overs  \
# 0     [2017-04-05]        male             T20          20
# 1     [2017-04-06]        male             T20          20
# 2     [2017-04-07]        male             T20          20
# 3     [2017-04-08]        male             T20          20
# 4     [2017-04-08]        male             T20          20
# ...            ...         ...             ...         ...
# 1090  [2016-05-22]        male             T20          20
# 1091  [2016-05-24]        male             T20          20
# 1092  [2016-05-25]        male             T20          20
# 1093  [2016-05-27]        male             T20          20
# 1094  [2016-05-29]        male             T20          20
#
#               info.outcome.winner info.player_of_match info.toss.decision  \
# 0             Sunrisers Hyderabad       [Yuvraj Singh]              field
# 1          Rising Pune Supergiant          [SPD Smith]              field
# 2           Kolkata Knight Riders            [CA Lynn]              field
# 3                 Kings XI Punjab         [GJ Maxwell]              field
# 4     Royal Challengers Bangalore          [KM Jadhav]                bat
# ...                           ...                  ...                ...
# 1090  Royal Challengers Bangalore            [V Kohli]              field
# 1091  Royal Challengers Bangalore     [AB de Villiers]              field
# 1092          Sunrisers Hyderabad       [MC Henriques]              field
# 1093          Sunrisers Hyderabad          [DA Warner]              field
# 1094          Sunrisers Hyderabad        [BCJ Cutting]                bat
#
#                  info.toss.winner                     info.umpires  \
# 0     Royal Challengers Bangalore          [AY Dandekar, NJ Llong]
# 1          Rising Pune Supergiant         [A Nand Kishore, S Ravi]
# 2           Kolkata Knight Riders         [Nitin Menon, CK Nandan]
# 3                 Kings XI Punjab    [AK Chaudhary, C Shamshuddin]
# 4     Royal Challengers Bangalore              [S Ravi, VK Sharma]
# ...                           ...                              ...
# 1090  Royal Challengers Bangalore   [A Nand Kishore, BNJ Oxenford]
# 1091  Royal Challengers Bangalore  [AK Chaudhary, HDPK Dharmasena]
# 1092        Kolkata Knight Riders       [M Erasmus, C Shamshuddin]
# 1093          Sunrisers Hyderabad           [M Erasmus, CK Nandan]
# 1094          Sunrisers Hyderabad  [HDPK Dharmasena, BNJ Oxenford]
#
#                                             info.venue  match_id
# 0            Rajiv Gandhi International Stadium, Uppal         1
# 1              Maharashtra Cricket Association Stadium         2
# 2               Saurashtra Cricket Association Stadium         3
# 3                               Holkar Cricket Stadium         4
# 4                                M.Chinnaswamy Stadium         5
# ...                                                ...       ...
# 1090  Shaheed Veer Narayan Singh International Stadium      1091
# 1091                             M Chinnaswamy Stadium      1092
# 1092                                  Feroz Shah Kotla      1093
# 1093                                  Feroz Shah Kotla      1094
# 1094                             M Chinnaswamy Stadium      1095
#
# [1095 rows x 15 columns]

# %% [markdown]
# Determining whether gender is affecting the data by analyzing its influence on the dataset.

# %%
final_df.shape
# Out:
# (1095, 15)

# %%
final_df['info.gender']
# Out:
# 0       male
# 1       male
# 2       male
# 3       male
# 4       male
#         ...
# 1090    male
# 1091    male
# 1092    male
# 1093    male
# 1094    male
# Name: info.gender, Length: 1095, dtype: object

# %%
if(final_df['info.gender'] == 'female').any():
    print("yes")
else:
    print("no")
# Out:
# no

# %% [markdown]
# Since the data only contains information about male players, the gender column is not providing any variability or meaningful insights. <br>
# Hence, it is being dropped.

# %%
final_df.drop(columns=['info.gender'], inplace=True)
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_18140\1180675058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'], inplace=True)

# %%
final_df
# Out:
#                                                 innings  info.city  \
# 0     [{'1st innings': {'team': 'Sunrisers Hyderabad...  Hyderabad
# 1     [{'1st innings': {'team': 'Mumbai Indians', 'd...       Pune
# 2     [{'1st innings': {'team': 'Gujarat Lions', 'de...     Rajkot
# 3     [{'1st innings': {'team': 'Rising Pune Supergi...     Indore
# 4     [{'1st innings': {'team': 'Royal Challengers B...  Bengaluru
# ...                                                 ...        ...
# 1090  [{'1st innings': {'team': 'Delhi Daredevils', ...     Raipur
# 1091  [{'1st innings': {'team': 'Gujarat Lions', 'de...  Bangalore
# 1092  [{'1st innings': {'team': 'Sunrisers Hyderabad...      Delhi
# 1093  [{'1st innings': {'team': 'Gujarat Lions', 'de...      Delhi
# 1094  [{'1st innings': {'team': 'Sunrisers Hyderabad...  Bangalore
#
#                                              info.teams info.competition  \
# 0     [Sunrisers Hyderabad, Royal Challengers Bangal...              IPL
# 1              [Rising Pune Supergiant, Mumbai Indians]              IPL
# 2                [Gujarat Lions, Kolkata Knight Riders]              IPL
# 3             [Kings XI Punjab, Rising Pune Supergiant]              IPL
# 4       [Royal Challengers Bangalore, Delhi Daredevils]              IPL
# ...                                                 ...              ...
# 1090    [Delhi Daredevils, Royal Challengers Bangalore]              IPL
# 1091       [Gujarat Lions, Royal Challengers Bangalore]              IPL
# 1092       [Sunrisers Hyderabad, Kolkata Knight Riders]              IPL
# 1093               [Gujarat Lions, Sunrisers Hyderabad]              IPL
# 1094  [Royal Challengers Bangalore, Sunrisers Hydera...              IPL
#
#         info.dates info.match_type  info.overs          info.outcome.winner  \
# 0     [2017-04-05]             T20          20          Sunrisers Hyderabad
# 1     [2017-04-06]             T20          20       Rising Pune Supergiant
# 2     [2017-04-07]             T20          20        Kolkata Knight Riders
# 3     [2017-04-08]             T20          20              Kings XI Punjab
# 4     [2017-04-08]             T20          20  Royal Challengers Bangalore
# ...            ...             ...         ...                          ...
# 1090  [2016-05-22]             T20          20  Royal Challengers Bangalore
# 1091  [2016-05-24]             T20          20  Royal Challengers Bangalore
# 1092  [2016-05-25]             T20          20          Sunrisers Hyderabad
# 1093  [2016-05-27]             T20          20          Sunrisers Hyderabad
# 1094  [2016-05-29]             T20          20          Sunrisers Hyderabad
#
#      info.player_of_match info.toss.decision             info.toss.winner  \
# 0          [Yuvraj Singh]              field  Royal Challengers Bangalore
# 1             [SPD Smith]              field       Rising Pune Supergiant
# 2               [CA Lynn]              field        Kolkata Knight Riders
# 3            [GJ Maxwell]              field              Kings XI Punjab
# 4             [KM Jadhav]                bat  Royal Challengers Bangalore
# ...                   ...                ...                          ...
# 1090            [V Kohli]              field  Royal Challengers Bangalore
# 1091     [AB de Villiers]              field  Royal Challengers Bangalore
# 1092       [MC Henriques]              field        Kolkata Knight Riders
# 1093          [DA Warner]              field          Sunrisers Hyderabad
# 1094        [BCJ Cutting]                bat          Sunrisers Hyderabad
#
#                          info.umpires  \
# 0             [AY Dandekar, NJ Llong]
# 1            [A Nand Kishore, S Ravi]
# 2            [Nitin Menon, CK Nandan]
# 3       [AK Chaudhary, C Shamshuddin]
# 4                 [S Ravi, VK Sharma]
# ...                               ...
# 1090   [A Nand Kishore, BNJ Oxenford]
# 1091  [AK Chaudhary, HDPK Dharmasena]
# 1092       [M Erasmus, C Shamshuddin]
# 1093           [M Erasmus, CK Nandan]
# 1094  [HDPK Dharmasena, BNJ Oxenford]
#
#                                             info.venue  match_id
# 0            Rajiv Gandhi International Stadium, Uppal         1
# 1              Maharashtra Cricket Association Stadium         2
# 2               Saurashtra Cricket Association Stadium         3
# 3                               Holkar Cricket Stadium         4
# 4                                M.Chinnaswamy Stadium         5
# ...                                                ...       ...
# 1090  Shaheed Veer Narayan Singh International Stadium      1091
# 1091                             M Chinnaswamy Stadium      1092
# 1092                                  Feroz Shah Kotla      1093
# 1093                                  Feroz Shah Kotla      1094
# 1094                             M Chinnaswamy Stadium      1095
#
# [1095 rows x 14 columns]

# %% [markdown]
# Checking the match type and the number of overs played to ensure that the dataset contains only T20 IPL matches.

# %%
final_df.shape
# Out:
# (1095, 14)

# %%
final_df['info.match_type'].value_counts()
# Out:
# info.match_type
# T20    1095
# Name: count, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# info.overs
# 20    1095
# Name: count, dtype: int64

# %% [markdown]
# Since all matches in the dataset belong to the T20 IPL format, these columns are redundant and are being removed.

# %%
final_df.drop(columns=['info.overs', 'info.match_type'], inplace=True)
# Out:
# C:\Users\Aaryan\AppData\Local\Temp\ipykernel_18140\1540112980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.overs', 'info.match_type'], inplace=True)

# %%
final_df.shape
# Out:
# (1095, 12)

# %% [markdown]
# To preserve the current state of the cleaned dataset, saving it as a pickle file. <br>
# This is acting as a checkpoint, allowing quick reloading without repeating the extraction and cleaning steps.

# %%
import pickle
pickle.dump(final_df, open('dataset_level1.pkl', 'wb'))

# %%
matches = pickle.load(open('dataset_level1.pkl', 'rb'))

# %%
matches
# Out:
#                                                 innings  info.city  \
# 0     [{'1st innings': {'team': 'Sunrisers Hyderabad...  Hyderabad
# 1     [{'1st innings': {'team': 'Mumbai Indians', 'd...       Pune
# 2     [{'1st innings': {'team': 'Gujarat Lions', 'de...     Rajkot
# 3     [{'1st innings': {'team': 'Rising Pune Supergi...     Indore
# 4     [{'1st innings': {'team': 'Royal Challengers B...  Bengaluru
# ...                                                 ...        ...
# 1090  [{'1st innings': {'team': 'Delhi Daredevils', ...     Raipur
# 1091  [{'1st innings': {'team': 'Gujarat Lions', 'de...  Bangalore
# 1092  [{'1st innings': {'team': 'Sunrisers Hyderabad...      Delhi
# 1093  [{'1st innings': {'team': 'Gujarat Lions', 'de...      Delhi
# 1094  [{'1st innings': {'team': 'Sunrisers Hyderabad...  Bangalore
#
#                                              info.teams info.competition  \
# 0     [Sunrisers Hyderabad, Royal Challengers Bangal...              IPL
# 1              [Rising Pune Supergiant, Mumbai Indians]              IPL
# 2                [Gujarat Lions, Kolkata Knight Riders]              IPL
# 3             [Kings XI Punjab, Rising Pune Supergiant]              IPL
# 4       [Royal Challengers Bangalore, Delhi Daredevils]              IPL
# ...                                                 ...              ...
# 1090    [Delhi Daredevils, Royal Challengers Bangalore]              IPL
# 1091       [Gujarat Lions, Royal Challengers Bangalore]              IPL
# 1092       [Sunrisers Hyderabad, Kolkata Knight Riders]              IPL
# 1093               [Gujarat Lions, Sunrisers Hyderabad]              IPL
# 1094  [Royal Challengers Bangalore, Sunrisers Hydera...              IPL
#
#         info.dates          info.outcome.winner info.player_of_match  \
# 0     [2017-04-05]          Sunrisers Hyderabad       [Yuvraj Singh]
# 1     [2017-04-06]       Rising Pune Supergiant          [SPD Smith]
# 2     [2017-04-07]        Kolkata Knight Riders            [CA Lynn]
# 3     [2017-04-08]              Kings XI Punjab         [GJ Maxwell]
# 4     [2017-04-08]  Royal Challengers Bangalore          [KM Jadhav]
# ...            ...                          ...                  ...
# 1090  [2016-05-22]  Royal Challengers Bangalore            [V Kohli]
# 1091  [2016-05-24]  Royal Challengers Bangalore     [AB de Villiers]
# 1092  [2016-05-25]          Sunrisers Hyderabad       [MC Henriques]
# 1093  [2016-05-27]          Sunrisers Hyderabad          [DA Warner]
# 1094  [2016-05-29]          Sunrisers Hyderabad        [BCJ Cutting]
#
#      info.toss.decision             info.toss.winner  \
# 0                 field  Royal Challengers Bangalore
# 1                 field       Rising Pune Supergiant
# 2                 field        Kolkata Knight Riders
# 3                 field              Kings XI Punjab
# 4                   bat  Royal Challengers Bangalore
# ...                 ...                          ...
# 1090              field  Royal Challengers Bangalore
# 1091              field  Royal Challengers Bangalore
# 1092              field        Kolkata Knight Riders
# 1093              field          Sunrisers Hyderabad
# 1094                bat          Sunrisers Hyderabad
#
#                          info.umpires  \
# 0             [AY Dandekar, NJ Llong]
# 1            [A Nand Kishore, S Ravi]
# 2            [Nitin Menon, CK Nandan]
# 3       [AK Chaudhary, C Shamshuddin]
# 4                 [S Ravi, VK Sharma]
# ...                               ...
# 1090   [A Nand Kishore, BNJ Oxenford]
# 1091  [AK Chaudhary, HDPK Dharmasena]
# 1092       [M Erasmus, C Shamshuddin]
# 1093           [M Erasmus, CK Nandan]
# 1094  [HDPK Dharmasena, BNJ Oxenford]
#
#                                             info.venue  match_id
# 0            Rajiv Gandhi International Stadium, Uppal         1
# 1              Maharashtra Cricket Association Stadium         2
# 2               Saurashtra Cricket Association Stadium         3
# 3                               Holkar Cricket Stadium         4
# 4                                M.Chinnaswamy Stadium         5
# ...                                                ...       ...
# 1090  Shaheed Veer Narayan Singh International Stadium      1091
# 1091                             M Chinnaswamy Stadium      1092
# 1092                                  Feroz Shah Kotla      1093
# 1093                                  Feroz Shah Kotla      1094
# 1094                             M Chinnaswamy Stadium      1095
#
# [1095 rows x 12 columns]

# %% [markdown]
# # Extract ball by ball data

# %% [markdown]
# To study the dataset better, extracting ball-by-ball data from the entire dataset. <br>
# Capturing details such as batsman, bowler, runs scored, dismissals, and extras. <br>
# This step is allowing the study of each individual delivery, making the data more detailed and efficient for further processing.

# %%
import pandas as pd

count = 1
delivery_df = pd.DataFrame()
dataframes = []

for index, row in matches.iterrows():

    count += 1
    match_id = []
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    city = []
    venue = []

    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])

            player_of_dismissed.append(ball[key].get('wicket', {}).get('player_out', '0'))
            
    loop_df = pd.DataFrame({
        'match_id': match_id,
        'team': teams,
        'batting_team': batting_team,
        'ball': ball_of_match,
        'batsman': batsman,
        'bowler': bowler,
        'runs': runs,
        'player_dismissed': player_of_dismissed,
        'city': city,
        'venue': venue
    })

    dataframes.append(loop_df)
    
delivery_df = pd.concat(dataframes, ignore_index=True)

# %%
delivery_df
# Out:
#         match_id                                               team  \
# 0              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# 1              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# 2              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# 3              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# 4              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# ...          ...                                                ...
# 135013      1096  [Royal Challengers Bangalore, Sunrisers Hydera...
# 135014      1096  [Royal Challengers Bangalore, Sunrisers Hydera...
# 135015      1096  [Royal Challengers Bangalore, Sunrisers Hydera...
# 135016      1096  [Royal Challengers Bangalore, Sunrisers Hydera...
# 135017      1096  [Royal Challengers Bangalore, Sunrisers Hydera...
#
#                batting_team  ball      batsman     bowler  runs  \
# 0       Sunrisers Hyderabad   0.1    DA Warner   TS Mills     0
# 1       Sunrisers Hyderabad   0.2    DA Warner   TS Mills     0
# 2       Sunrisers Hyderabad   0.3    DA Warner   TS Mills     4
# 3       Sunrisers Hyderabad   0.4    DA Warner   TS Mills     0
# 4       Sunrisers Hyderabad   0.5    DA Warner   TS Mills     2
# ...                     ...   ...          ...        ...   ...
# 135013  Sunrisers Hyderabad  19.2  BCJ Cutting  SR Watson     6
# 135014  Sunrisers Hyderabad  19.3  BCJ Cutting  SR Watson     6
# 135015  Sunrisers Hyderabad  19.4  BCJ Cutting  SR Watson     1
# 135016  Sunrisers Hyderabad  19.5      B Kumar  SR Watson     1
# 135017  Sunrisers Hyderabad  19.6  BCJ Cutting  SR Watson     6
#
#        player_dismissed       city                                      venue
# 0                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 1                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 2                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 3                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 4                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# ...                 ...        ...                                        ...
# 135013                0  Bangalore                      M Chinnaswamy Stadium
# 135014                0  Bangalore                      M Chinnaswamy Stadium
# 135015                0  Bangalore                      M Chinnaswamy Stadium
# 135016                0  Bangalore                      M Chinnaswamy Stadium
# 135017                0  Bangalore                      M Chinnaswamy Stadium
#
# [135018 rows x 10 columns]

# %% [markdown]
# To enhance data clarity, separating the batting team and bowling team for each delivery. <br>
# This distinction is being made to understand team-wise performance and analyze match dynamics.

# %%
def bowl(row):
    for team in row['team']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df.drop(columns=['team'], inplace=True)

# %%
delivery_df
# Out:
#         match_id         batting_team  ball      batsman     bowler  runs  \
# 0              2  Sunrisers Hyderabad   0.1    DA Warner   TS Mills     0
# 1              2  Sunrisers Hyderabad   0.2    DA Warner   TS Mills     0
# 2              2  Sunrisers Hyderabad   0.3    DA Warner   TS Mills     4
# 3              2  Sunrisers Hyderabad   0.4    DA Warner   TS Mills     0
# 4              2  Sunrisers Hyderabad   0.5    DA Warner   TS Mills     2
# ...          ...                  ...   ...          ...        ...   ...
# 135013      1096  Sunrisers Hyderabad  19.2  BCJ Cutting  SR Watson     6
# 135014      1096  Sunrisers Hyderabad  19.3  BCJ Cutting  SR Watson     6
# 135015      1096  Sunrisers Hyderabad  19.4  BCJ Cutting  SR Watson     1
# 135016      1096  Sunrisers Hyderabad  19.5      B Kumar  SR Watson     1
# 135017      1096  Sunrisers Hyderabad  19.6  BCJ Cutting  SR Watson     6
#
#        player_dismissed       city                                      venue  \
# 0                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 1                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 2                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 3                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 4                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# ...                 ...        ...                                        ...
# 135013                0  Bangalore                      M Chinnaswamy Stadium
# 135014                0  Bangalore                      M Chinnaswamy Stadium
# 135015                0  Bangalore                      M Chinnaswamy Stadium
# 135016                0  Bangalore                      M Chinnaswamy Stadium
# 135017                0  Bangalore                      M Chinnaswamy Stadium
#
#                        bowling_team
# 0       Royal Challengers Bangalore
# 1       Royal Challengers Bangalore
# 2       Royal Challengers Bangalore
# 3       Royal Challengers Bangalore
# 4       Royal Challengers Bangalore
# ...                             ...
# 135013  Royal Challengers Bangalore
# 135014  Royal Challengers Bangalore
# 135015  Royal Challengers Bangalore
# 135016  Royal Challengers Bangalore
# 135017  Royal Challengers Bangalore
#
# [135018 rows x 10 columns]

# %%
delivery_df['batting_team'].value_counts()
# Out:
# batting_team
# Mumbai Indians                 16675
# Chennai Super Kings            16085
# Royal Challengers Bangalore    14761
# Kolkata Knight Riders          14719
# Rajasthan Royals               12730
# Kings XI Punjab                11869
# Sunrisers Hyderabad            11645
# Delhi Daredevils                8753
# Deccan Chargers                 5280
# Delhi Capitals                  5105
# Punjab Kings                    3882
# Lucknow Super Giants            2874
# Gujarat Titans                  2614
# Pune Warriors                   2448
# Gujarat Lions                   1726
# Royal Challengers Bengaluru     1133
# Rising Pune Supergiant           994
# Kochi Tuskers Kerala             876
# Rising Pune Supergiants          849
# Name: count, dtype: int64

# %%
output = delivery_df[['match_id', 'batting_team', 'bowling_team', 'ball', 'runs', 'player_dismissed', 'city', 'venue']]

# %%
output
# Out:
#         match_id         batting_team                 bowling_team  ball  \
# 0              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.1
# 1              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.2
# 2              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.3
# 3              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.4
# 4              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.5
# ...          ...                  ...                          ...   ...
# 135013      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.2
# 135014      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.3
# 135015      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.4
# 135016      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.5
# 135017      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.6
#
#         runs player_dismissed       city  \
# 0          0                0  Hyderabad
# 1          0                0  Hyderabad
# 2          4                0  Hyderabad
# 3          0                0  Hyderabad
# 4          2                0  Hyderabad
# ...      ...              ...        ...
# 135013     6                0  Bangalore
# 135014     6                0  Bangalore
# 135015     1                0  Bangalore
# 135016     1                0  Bangalore
# 135017     6                0  Bangalore
#
#                                             venue
# 0       Rajiv Gandhi International Stadium, Uppal
# 1       Rajiv Gandhi International Stadium, Uppal
# 2       Rajiv Gandhi International Stadium, Uppal
# 3       Rajiv Gandhi International Stadium, Uppal
# 4       Rajiv Gandhi International Stadium, Uppal
# ...                                           ...
# 135013                      M Chinnaswamy Stadium
# 135014                      M Chinnaswamy Stadium
# 135015                      M Chinnaswamy Stadium
# 135016                      M Chinnaswamy Stadium
# 135017                      M Chinnaswamy Stadium
#
# [135018 rows x 8 columns]

# %%
if(output['player_dismissed'] != 0).any():
    print("yes")
# Out:
# yes

# %%
output['player_dismissed'].value_counts()
# Out:
# player_dismissed
# 0                128323
# RG Sharma           119
# S Dhawan            115
# V Kohli             114
# KD Karthik          100
#                   ...
# DJ Muthuswami         1
# KC Cariappa           1
# P Sahu                1
# PSP Handscomb         1
# F Behardien           1
# Name: count, Length: 541, dtype: int64

# %%
output['city'].value_counts()
# Out:
# city
# Mumbai            21504
# Kolkata           11380
# Delhi             11059
# Chennai           10554
# Hyderabad          9499
# Bangalore          7869
# Chandigarh         7449
# Jaipur             7073
# Pune               6300
# Abu Dhabi          4565
# Ahmedabad          4450
# Bengaluru          3521
# Visakhapatnam      1869
# Durban             1858
# Lucknow            1738
# Dubai              1623
# Dharamsala         1618
# Centurion          1486
# Sharjah            1245
# Rajkot             1229
# Navi Mumbai        1133
# Indore             1082
# Johannesburg        995
# Port Elizabeth      870
# Cuttack             856
# Ranchi              837
# Cape Town           813
# Raipur              742
# Mohali              622
# Kochi               603
# Kanpur              492
# East London         380
# Guwahati            372
# Nagpur              370
# Kimberley           368
# Bloemfontein        251
# Name: count, dtype: int64

# %% [markdown]
# After extracting ball-by-ball data and separating the batting and bowling teams, saving the updated dataset as another pickle file. <br>
# This is ensuring that progress is preserved, allowing efficient reloading without reprocessing previous steps.

# %%
pickle.dump(output, open('dataset_level2.pkl', 'wb'))

# %%
output_chk = pickle.load(open('dataset_level2.pkl', 'rb'))

# %%
output_chk
# Out:
#         match_id         batting_team                 bowling_team  ball  \
# 0              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.1
# 1              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.2
# 2              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.3
# 3              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.4
# 4              2  Sunrisers Hyderabad  Royal Challengers Bangalore   0.5
# ...          ...                  ...                          ...   ...
# 135013      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.2
# 135014      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.3
# 135015      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.4
# 135016      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.5
# 135017      1096  Sunrisers Hyderabad  Royal Challengers Bangalore  19.6
#
#         runs player_dismissed       city  \
# 0          0                0  Hyderabad
# 1          0                0  Hyderabad
# 2          4                0  Hyderabad
# 3          0                0  Hyderabad
# 4          2                0  Hyderabad
# ...      ...              ...        ...
# 135013     6                0  Bangalore
# 135014     6                0  Bangalore
# 135015     1                0  Bangalore
# 135016     1                0  Bangalore
# 135017     6                0  Bangalore
#
#                                             venue
# 0       Rajiv Gandhi International Stadium, Uppal
# 1       Rajiv Gandhi International Stadium, Uppal
# 2       Rajiv Gandhi International Stadium, Uppal
# 3       Rajiv Gandhi International Stadium, Uppal
# 4       Rajiv Gandhi International Stadium, Uppal
# ...                                           ...
# 135013                      M Chinnaswamy Stadium
# 135014                      M Chinnaswamy Stadium
# 135015                      M Chinnaswamy Stadium
# 135016                      M Chinnaswamy Stadium
# 135017                      M Chinnaswamy Stadium
#
# [135018 rows x 8 columns]
